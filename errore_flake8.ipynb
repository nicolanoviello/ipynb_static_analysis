# %%
# Un semplice test
#import time

# %%
time.sleep(5)
print('stampa dopo timer')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e57a23797b1e> in <module>()
# ----> 1 time.sleep(5)
#       2 print('stampa dopo timer')
#
# NameError: name 'time' is not defined
